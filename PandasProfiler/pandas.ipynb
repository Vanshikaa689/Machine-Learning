# %% [markdown]
# ## pandas profiling
# (doesn't work with newer version of numba)

# %%
# !pip install pandas-profiling

# %%
import pandas as pd
df = pd.read_csv('train.csv')

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file("report.html")

# %% [markdown]
# ## y-data profiling

# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (3.9.1.post1)
# Requirement already satisfied: pydantic>=2 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (2.9.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (3.1.4)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (1.24.3)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.4-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.4.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (1.9.3)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.7.0)
# Requirement already satisfied: pillow in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (2.9.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from numba<1,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from pydantic>=2->ydata-profiling) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from pydantic>=2->ydata-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.12.14)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: colorama in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: six>=1.5 in c:\users\vansh\anaconda3\envs\trch\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.5->ydata-profiling) (1.16.0)
# Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl (390 kB)
#    ---------------------------------------- 0.0/390.9 kB ? eta -:--:--
#    --------------------------------------- 390.9/390.9 kB 25.4 MB/s eta 0:00:00
# Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading statsmodels-0.14.4-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/9.9 MB 14.2 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.3/9.9 MB 16.1 MB/s eta 0:00:01
#    --------- ------------------------------ 2.3/9.9 MB 18.4 MB/s eta 0:00:01
#    ------------ --------------------------- 3.1/9.9 MB 18.2 MB/s eta 0:00:01
#    --------------- ------------------------ 3.8/9.9 MB 18.7 MB/s eta 0:00:01
#    ------------------ --------------------- 4.6/9.9 MB 15.5 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.9 MB 14.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.9 MB 14.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.9/9.9 MB 15.2 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 16.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.0/9.9 MB 16.5 MB/s eta 0:00:01
#    ------------------------------------ --- 9.0/9.9 MB 16.5 MB/s eta 0:00:01
#    -------------------------------------- - 9.6/9.9 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  9.9/9.9 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 10.0 MB/s eta 0:00:00
# Downloading typeguard-4.4.1-py3-none-any.whl (35 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.8 kB ? eta -:--:--
#    ---------------------------------------- 104.8/104.8 kB ? eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.9 kB ? eta -:--:--
#    --------------------------------------- 232.9/232.9 kB 14.8 MB/s eta 0:00:00
# Installing collected packages: typeguard, patsy, multimethod, dacite, visions, statsmodels, ydata-profiling
#   Attempting uninstall: multimethod
#     Found existing installation: multimethod 2.0
#     Uninstalling multimethod-2.0:
#       Successfully uninstalled multimethod-2.0
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# Successfully installed dacite-1.8.1 multimethod-1.12 patsy-1.0.1 statsmodels-0.14.4 typeguard-4.4.1 visions-0.7.6 ydata-profiling-4.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.

# %%
from ydata_profiling import ProfileReport

# Create the profile report
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)

# Save the report to an HTML file
profile.to_file("report.html")
# Out:
# Summarize dataset: 100%|██████████| 47/47 [00:06<00:00,  6.78it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:09<00:00,  9.25s/it]
# Render HTML: 100%|██████████| 1/1 [00:02<00:00,  2.09s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 17.56it/s]
